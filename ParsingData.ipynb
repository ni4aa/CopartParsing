# %%
import pandas as pd
import numpy as np
import matplotlib as plt
import seaborn as sns

# %%
from Parser import CopartParse

# %%
parser = CopartParse(url='https://www.copart.com/ru/lotSearchResults?free=false&searchCriteria=%7B%22query%22:%5B%22*%22%5D,%22filter%22:%7B%22VEHT%22:%5B%22vehicle_type_code:VEHTYPE_V%22%5D,%22ODM%22:%5B%22odometer_reading_received:%5B0%20TO%209999999%5D%22%5D,%22YEAR%22:%5B%22lot_year:%5B2014%20TO%202025%5D%22%5D%7D,%22searchName%22:%22%22,%22watchListOnly%22:false,%22freeFormSearch%22:false%7D%20&displayStr=%D0%9F%D0%BE%D0%B8%D1%81%D0%BA%20%D1%82%D1%80%D0%B0%D0%BD%D1%81%D0%BF%D0%BE%D1%80%D1%82%D0%BD%D1%8B%D1%85%20%D1%81%D1%80%D0%B5%D0%B4%D1%81%D1%82%D0%B2&from=%2FvehicleFinder&fromSource=widget', count_page=20)

# %%
parser.parse()
# Out:
# ---------------------------------------------------------------------------
# WebDriverException                        Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 parser.parse()
#
# File d:\proga\python\DS\CopartParsing\Parser.py:105, in CopartParse.parse(self, data)
#     103     self.__set_up()
#     104     self.__get_url()
# --> 105     self.__paginator()
#     106 finally:
#     107     self.quit()
#
# File d:\proga\python\DS\CopartParsing\Parser.py:28, in CopartParse.__paginator(self)
#      25 WebDriverWait(self.driver, 45).until(EC.presence_of_element_located((
#      26             By.CSS_SELECTOR, '[class="p-paginator-icon pi pi-angle-right"]')))
#      27 while self.driver.find_elements(By.CSS_SELECTOR, '[class="p-paginator-icon pi pi-angle-right"]') and self.count_page > self.number_of_page:
# ---> 28     self.__parse_page()
#      30     self.number_of_page += 1
#      32     if self.number_of_page == self.count_page:
#
# ...

# %%
df = parser.data

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 264 entries, 0 to 263
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   lot_number    264 non-null    int64
#  1   miles         264 non-null    float64
#  2   transmission  264 non-null    object
#  3   fuel          264 non-null    object
#  4   drive         264 non-null    object
#  5   name          264 non-null    object
#  6   make          264 non-null    object
#  7   year          264 non-null    int64
#  8   auction       264 non-null    object
# dtypes: float64(1), int64(2), object(6)
# memory usage: 18.7+ KB

# %%
df.drop_duplicates()
df.shape
# Out:
# (264, 9)

# %%
sns.pairplot(df[['miles', 'year']])

# %%
df.to_csv("data260.csv")
